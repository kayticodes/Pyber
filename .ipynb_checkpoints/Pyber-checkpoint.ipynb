# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load 
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# %%
# Read the City and Ride Data
city_df = pd.read_csv(city_data_to_load)
ride_df = pd.read_csv(ride_data_to_load)

# %%
# Display city data table for preview
city_df.head(5)
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
# Display Ride data table for preview
ride_df.head(5)
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
# Combine the data into a single dataset
merged_df = pd.merge(ride_df, city_df, on="city")
# Display the data table for preview
merged_df.head(5)
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %%
#get a rough idea of the merged data set 
merged_df.describe()
# Out:
#               fare       ride_id  driver_count
# count  2375.000000  2.375000e+03   2375.000000
# mean     26.753112  4.887270e+12     28.930105
# std      12.109465  2.907361e+12     20.666306
# min       4.050000  3.218337e+08      1.000000
# 25%      17.190000  2.381175e+12     11.000000
# 50%      26.600000  4.748541e+12     23.000000
# 75%      36.645000  7.461936e+12     45.000000
# max      58.550000  9.991538e+12     73.000000

# %%
#Establish how many unique city types there are 
merged_df['type'].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
#Establish how many cities we're working with 
#merged_df['city'].unique()

# %%
#Count how many cities we're working with
city_count= merged_df.groupby('type')[['city']].nunique()
city_count
# Out:
#           city
# type
# Rural       18
# Suburban    36
# Urban       66

# %%
#we can already tell that we have significantly more urban cities in comparison to suburban and rural city types

# %%
#group the cities together 
city_groups = merged_df.groupby('city')

# %%
rides=city_groups ['ride_id'].count

# %%
#find out the average fare (y axis)
ave_fare= city_groups ['fare'].mean()
#ave_fare

# %%
grouped_drivers = city_df.groupby(['city', 'driver_count'])
#grouped_drivers.head(5)
# Out:
#                      city  driver_count      type
# 0             Richardfort            38     Urban
# 1            Williamsstad            59     Urban
# 2             Port Angela            67     Urban
# 3              Rodneyfort            34     Urban
# 4             West Robert            39     Urban
# 5            West Anthony            70     Urban
# 6             West Angela            48     Urban
# 7           Martinezhaven            25     Urban
# 8               Karenberg            22     Urban
# 9             Barajasview            26     Urban
# 10             Robertport            12     Urban
# 11           Joneschester            39     Urban
# 12                Leahton            17     Urban
# 13   West Christopherberg            32     Urban
# 14                Johnton            27     Urban
# 15           Reynoldsfurt            67     Urban
# 16             Port David             7     Urban
# 17    New Kimberlyborough            33     Urban
# ...

# %%
# Tell matplotlib to create a scatter plot based upon the above data

# Without scoop_price
plt.scatter(city_rides, ave_fare, marker="o", facecolors=[ "b"], edgecolors="black")

# BONUS: With scoop_price set to the scalar value
# scoop_price = [89, 18, 10, 28, 79, 46, 29, 38, 89, 26, 45, 62]
# plt.scatter(temp, sales, marker="o", facecolors="red", edgecolors="black", s=scoop_price)
